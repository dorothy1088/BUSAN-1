# %%
# 변수
# 변수는 메모리상 지정된 값을 가리키는 이름입니다.
#파이썬에서는 어떠한 변수에 값을 위치시킬 때 (할당할 때) 해당 변수의 공간에 대한 자료형을 
#미리 지정해 줄 필요가 없습니다. 이를 동적 타이핑(dynamic typing)이라고 일컫습니다.
# 변수에는 값(개체)자체를 보관하는 것이 아니라 메모리 어딘가에 적재된 객체라는 것의 위치를
# 저장하는 방식으로 동작합니다.

## 변수의 할당과 초기화
#변수를 만들고 해당 변수에 값을 위치시키는 것들을 일컫는 말이 있습니다
# 변수라는 공간을 만들거나 이미 있는 변수에 값을 재위치 시키는 것을 할당(allocation)이라고 일컫습니다
# 그리고 변수를 생성함과 동시에 생성된 변수에 값을 할당시키는 행위는 변수의 초기화라고 일컫습니다

## 변수의 초기화
#초기화는 비어있는 변수라는 공간을 생성함과 동시에 값을 위치시키는 행위입니다
#파이썬에서는 변수를 다음과 같이 초기화 할 수 있습니다.

'''text
변수이름 = 값
'''

# 초기화
