# %%
#자료형
#프로그래밍에서 값을 어떻게 저장하고 다룰지를 정해주는 일종의 "값의 종류"

#숫자 자료형
#숫자와 관련된 자료를 처리하기 위한 방식을 정의

#정수 자료형
#0-9,+,-와 같이 실수가 아닌 정수를 처리하기 위한 형식

#실수 자료형
#0-9,+,-와 .(실수를 위한 부동소수점 floating point)을 포함한 실수를 처리하기 위한 형식

#문자 자료형(얼레이 - 배열 리스트만 사용)
#글자의 나열(문자열)을 처리하기 위한 방식

#시퀀스 자료형
#메모리에 연속적으로 값을 올려 처리하기 위한 형식

#논리 자료형boolean type
#참/거짓을 표편하고 처리하기 위한 형식

#none 자료형
#실제 값이 없음을 처리하기 위한 형식

#정수 자료형
#실
